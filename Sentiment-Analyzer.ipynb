# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer   
def output_scenti(m):
    analyzer = SentimentIntensityAnalyzer()   
    sentiment_dict = analyzer.polarity_scores(m) 
    return sentiment_dict['compound']
# Driver code 
if __name__ == "__main__" : 
    print("\t\t\t\t\t-----> Welcome to Sentiment Analyser <-----\n")
    intro=str(input("\nTo know about Sentiment Analyser Enter Yes or No to Skip Intro :")).capitalize()
    if intro.startswith("YES") or intro.startswith("Y"):
        # %run Intro-Sentiment-Analysis.ipynb
    print("\nOkay!! then Lets Quickly get into Simple Quiz to Know about you:\n")
    name=str(input("Enter Your Name :"))
    i=0
    count=0
    answers=["It was just Awesome","Okay it was not Bad","It was a Bad Day","It was Worse","Life is just Awesome","Life is all about good and bad","Life is so boring","I hate this Life","I hate apology","I frequently apologize","Apologize according to suitation","self-respect is lost"]
    while(True):
        if i==1:
            break
        q1=input("\nI.How was your day ?\n\n>>>Enter Your Choice: \n\n a) It was just Awesome \t b) Okay it was not Bad \t c) It was a Bad Day \t d) It was Worse \n\n").capitalize()
        if q1.startswith('A'):
            count+=output_scenti(answers[0])
        elif q1.startswith('B'):
            count+=output_scenti(answers[1])
        elif q1.startswith('C'):
            count+=output_scenti(answers[2])
        elif q1.startswith('D'):
            count+=output_scenti(answers[4])
        else:
            print("\nOops!! Enter Valid Choice like a or b or c or d")
            continue
        i+=1
    while(True):
        if i==2:
            break
        q2=input("\nII.Define Life in your prospective ?\n\n>>>Enter Your Choice: \n\n a) Life is just Awesome \t b) Life is all about good and bad \t c) Life is so boring \t d) I hate this Life \n\n").capitalize()
        if q2.startswith('A'):
            count+=output_scenti(answers[3])
        elif q2.startswith('B'):
            count+=output_scenti(answers[4])
        elif q2.startswith('C'):
            count+=output_scenti(answers[5])
        elif q2.startswith('D'):
            count+=output_scenti(answers[6])
        else:
            print("\nOops!! Enter Valid Choice like a or b or c or d")
            continue
        i+=1
    while(True):
        if i==3:
            break
        q3=input("\nIII.Do you apologize too often ?\n\n>>>Enter Your Choice: \n\n a) I hate apology \t b) I frequently apologize \t c) Apologize according to suitation \t d)self-respect is lost \n\n").capitalize()
        if q3.startswith('A'):
            count+=output_scenti(answers[7])
        elif q3.startswith('B'):
            count+=output_scenti(answers[8])
        elif q3.startswith('C'):
            count+=output_scenti(answers[9])
        elif q3.startswith('D'):
            count+=output_scenti(answers[10])
        else:
            print("\nOops!! Enter Valid Choice like a or b or c or d")
            continue
        i+=1
    print("\n>>>A Fact about you:\n\n", end = " ") 
    if (count/3) >= 0.05 : 
        print("Hey!!",name,"Awesome and keep going your such a Positive thinking Person :)") 
    elif (count/3) <= - 0.05 : 
        print("Hey!!",name,"Dont Worry :( You can be the best Just bring postivity in You:)") 
    else : 
        print("Hey!!",name,"Great build more positivity in you which makes You strong :)")
    query=str(input("\nWanna Know Your Senitiment Analysis Score ??")).capitalize()
    if query.startswith("YES") or query.startswith("Y"):
        print("\n\n>>> Hey",name,"Based on the Quiz answer currently your Sentimental Analysis Score is:",(count/3))
        print("\n\n >> NOTE : +ve sign indicates => Positivity ( >= 0.05 ) \n\n\t  Neutral => ( > -0.05 and < 0.05) \n\n\t -ve sign indicates => Negativity ( <= -0.05) ")
    print("\n\n>>> Tip of the Day :\n")
    # %run Quotes-NLP.ipynb
    print("\n\n\t\t\t\t>>>> Raise the VOLUME !!Be Relax with suggested playlist")
    if((count/3)>-0.05):
        print("\n\n\t\t\t\tPlaying......")
        # %run hplaylist.ipynb
    else:
        print("\n\n\t\t\t\tPlaying......")
        # %run splaylist.ipynb
